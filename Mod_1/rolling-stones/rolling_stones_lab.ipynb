# %%
import csv 
from collections import OrderedDict

with open('data.csv') as f:
        reader = csv.DictReader(f)
        
        albums_info = []
        
        for row in reader:
            albums_info.append(row)
            
print(albums_info[1])
# Out:
# OrderedDict([('number', '2'), ('year', '1966'), ('album', 'Pet Sounds'), ('artist', 'The Beach Boys'), ('genre', 'Rock'), ('subgenre', 'Pop Rock, Psychedelic Rock')])

# %%
def find_by_name(album_name):
    for index in range(0,len(albums_info)):
        if albums_info[index]['album'] == album_name:
            return(dict.values(albums_info[index]))
            
    else:
          return None

# %%
find_by_name('Revolver')
# Out:
# dict_values(['3', '1966', 'Revolver', 'The Beatles', 'Rock', 'Psychedelic Rock, Pop Rock'])

# %%
def find_by_rank(album_rank):
    for index in range(0, len(albums_info)):
        if albums_info[index]['number'] == album_rank:
            return(dict.values(albums_info[index]))
            
    else:
          return None

# %%
find_by_rank('6')
# Out:
# dict_values(['6', '1971', "What's Going On", 'Marvin Gaye', 'Funk / Soul', 'Soul'])

# %%
def find_by_year(album_year):
    albums_in_year = []
    empty_list = []
    for index in range(0, len(albums_info)):
        if albums_info[index]['year'] == album_year:
            albums_in_year.append(albums_info[index]['album'])
    
        else: 
            None 
        
    return albums_in_year

# %%
find_by_year('1999')
# Out:
# ['The Neil Diamond Collection',
#  'The Slim Shady LP',
#  'Play',
#  'Californication',
#  'Mule Variations',
#  '69 Love Songs']

# %%
def find_by_years(start_year, end_year):
    albums_in_year = []
    for index in range(0, len(albums_info)):
        if int(start_year) <= int(albums_info[index]['year']) <= int(end_year):
            albums_in_year.append(albums_info[index]['album']) 
            
        else:
            None 

    return albums_in_year

# %%
find_by_years('1997', '2000')
# Out:
# ['Kid A',
#  'OK Computer',
#  'The Neil Diamond Collection',
#  'The Ultimate Collection',
#  'The Marshall Mathers LP',
#  'The Velvet Rope',
#  'Dig Me Out',
#  'The Slim Shady LP',
#  "All That You Can't Leave Behind",
#  'Car Wheels on a Gravel Road',
#  'The Miseducation of Lauryn Hill',
#  'Play',
#  'Stankonia',
#  'Ray of Light',
#  'Californication',
#  'Time Out of Mind',
#  'Mule Variations',
#  'Stories From the City, Stories From the Sea',
#  '69 Love Songs',
#  'Life After Death',
#  'Voodoo',
#  'Aquemini']

# %%
def find_by_ranks(start_rank, end_rank):
    albums_in_ranks = []
    for index in range(0, len(albums_info)):
        if int(start_rank) <= int(albums_info[index]['number']) <= int(end_rank):
            albums_in_ranks.append(albums_info[index]['album']) 
            
        else:
            None 

    return albums_in_ranks

# %%
find_by_ranks('55', '56')
# Out:
# ['Electric Ladyland', 'Elvis Presley']

# %%
def all_titles():
    album_titles = []
    for index in range(0,len(albums_info)):
        album_titles.append(albums_info[index]['album'])
        
    return album_titles

# %%
all_titles()
# Out:
# ["Sgt. Pepper's Lonely Hearts Club Band",
#  'Pet Sounds',
#  'Revolver',
#  'Highway 61 Revisited',
#  'Rubber Soul',
#  "What's Going On",
#  'Exile on Main St.',
#  'London Calling',
#  'Blonde on Blonde',
#  'The Beatles ("The White Album")',
#  'The Sun Sessions',
#  'Kind of Blue',
#  'The Velvet Underground & Nico',
#  'Abbey Road',
#  'Are You Experienced',
#  'Blood on the Tracks',
#  'Nevermind',
#  'Born to Run',
#  'Astral Weeks',
#  'Thriller',
#  'The Great Twenty Eight',
#  'The Complete Recordings',
#  'John Lennon/Plastic Ono Band',
#  'Innervisions',
#  'Live at the Apollo, 1962',
#  'Rumours',
#  'The Joshua Tree',
#  "Who's Next",
#  'Led Zeppelin',
#  'Blue',
#  'Bringing It All Back Home',
#  'Let It Bleed',
#  'Ramones',
#  'Music From Big Pink',
#  'The Rise and Fall of Ziggy Stardust and the Spiders From Mars',
#  'Tapestry',
#  'Hotel California',
#  'The Anthology',
#  'Please Please Me',
#  'Forever Changes',
# ...

# %%
def all_artists():
    album_artists = []
    for index in range(0,len(albums_info)):
        album_artists.append(albums_info[index]['artist'])
        
    return album_artists

# %%
all_artists()
# Out:
# ['The Beatles',
#  'The Beach Boys',
#  'The Beatles',
#  'Bob Dylan',
#  'The Beatles',
#  'Marvin Gaye',
#  'The Rolling Stones',
#  'The Clash',
#  'Bob Dylan',
#  'The Beatles',
#  'Elvis Presley',
#  'Miles Davis',
#  'The Velvet Underground',
#  'The Beatles',
#  'The Jimi Hendrix Experience',
#  'Bob Dylan',
#  'Nirvana',
#  'Bruce Springsteen',
#  'Van Morrison',
#  'Michael Jackson',
#  'Chuck Berry',
#  'Robert Johnson',
#  'John Lennon / Plastic Ono Band',
#  'Stevie Wonder',
#  'James Brown',
#  'Fleetwood Mac',
#  'U2',
#  'The Who',
#  'Led Zeppelin',
#  'Joni Mitchell',
#  'Bob Dylan',
#  'The Rolling Stones',
#  'Ramones',
#  'The Band',
#  'David Bowie',
#  'Carole King',
#  'Eagles',
#  'Muddy Waters',
#  'The Beatles',
#  'Love',
#  'Sex Pistols',
#  'The Doors',
#  'Pink Floyd',
#  'Patti Smith',
#  'The Band',
#  'Bob Marley & The Wailers',
#  'John Coltrane',
#  'Public Enemy',
#  'The Allman Brothers Band',
#  'Little Richard',
#  'Simon & Garfunkel',
# ...

# %%
#Artists with the most albums 
#Returns the artist with the highest amount of albums on the list of top albums

def artists_most_albums():
    artists_album_count = {}
    for index in range(0, len(all_artists())):
        if all_artists()[index] in artists_album_count:
            artists_album_count[all_artists()[index]] += 1
        else:
            artists_album_count[all_artists()[index]] = 1
            
    max_albums= max(artists_album_count.values())
    
    max_albums_artists = []
    for k,v in artists_album_count.items():
        if v == max_albums:
            max_albums_artists.append(k)
    return max_albums_artists

# %%
artists_most_albums()
# Out:
# ['The Beatles', 'Bob Dylan', 'The Rolling Stones']

# %%
def most_popular_word():
    all_words = list(all_titles().split(''))
    word_count = {}
    for index in range(0, len(all_words)):
        if all_words[index] in word_count:
            word_count[all_words[index]] += 1
        else:
            word_count[all_words[index]] = 1
            
    max_word= max(word_count.values())
    
    max_words = []
    for k,v in word_count.items():
        if v == max_word:
            max_words.append(k)
    return max_words

# %%
most_popular_word()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-197-5d4d67a8c97e> in <module>
# ----> 1 most_popular_word()
#
# <ipython-input-196-b201a98c24f4> in most_popular_word()
#       1 def most_popular_word():
# ----> 2     all_words = list(all_titles().split(' '))
#       3     word_count = {}
#       4     for index in range(0, len(all_words)):
#       5         if all_words[index] in word_count:
#
# AttributeError: 'list' object has no attribute 'split'
